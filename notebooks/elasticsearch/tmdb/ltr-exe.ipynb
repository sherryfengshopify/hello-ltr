# %%
from ltr.client import ElasticClient
client = ElasticClient()

# %%
from ltr import download
corpus='http://es-learn-to-rank.labs.o19s.com/tmdb.json'
judgments='http://es-learn-to-rank.labs.o19s.com/title_judgments.txt'

download([corpus, judgments], dest='data/');
from ltr.index import rebuild
from ltr.helpers.movies import indexable_movies

movies=indexable_movies(movies='data/tmdb.json')
rebuild(client, index='tmdb', doc_src=movies)
# Out:
# data/tmdb.json already exists
# data/title_judgments.txt already exists
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     250
# --> 251             response = self.pool.urlopen(
#     252                 method, url, body, retries=Retry(False), headers=request_headers, **kw
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784
# --> 785             retries = retries.increment(
#     786                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     524             # Disabled, indicate to re-raise the error.
# --> 525             raise six.reraise(type(error), error, _stacktrace)
#     526
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     769                 raise value.with_traceback(tb)
# --> 770             raise value
#     771         finally:
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# ~/opt/anaconda3/envs/es/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# ~/opt/anaconda3/envs/es/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ~/opt/anaconda3/envs/es/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1273             raise CannotSendHeader()
# -> 1274         self._send_output(message_body, encode_chunked=encode_chunked)
#    1275
#
# ~/opt/anaconda3/envs/es/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1033         del self._buffer[:]
# -> 1034         self.send(msg)
#    1035
#
# ~/opt/anaconda3/envs/es/lib/python3.9/http/client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f9ae84383a0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /var/folders/dr/fvwczs956z99xnld03ndvlzm0000gn/T/ipykernel_912/3450406853.py in <module>
#       8
#       9 movies=indexable_movies(movies='data/tmdb.json')
# ---> 10 rebuild(client, index='tmdb', doc_src=movies)
#
# ~/Documents/hello-ltr/ltr/index.py in rebuild(client, index, doc_src, force)
#       7     """
#       8
# ----> 9     if client.check_index_exists(index):
#      10         if (force):
#      11             client.delete_index(index)
#
# ~/Documents/hello-ltr/ltr/client/elastic_client.py in check_index_exists(self, index)
#      61
#      62     def check_index_exists(self, index):
# ---> 63         return self.es.indices.exists(index=index)
#      64
#      65     def delete_index(self, index):
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     166                 if p in kwargs:
#     167                     params[p] = kwargs.pop(p)
# --> 168             return func(*args, params=params, headers=headers, **kwargs)
#     169
#     170         return _wrapped
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/elasticsearch/client/indices.py in exists(self, index, params, headers)
#     330             raise ValueError("Empty value passed for a required argument 'index'.")
#     331
# --> 332         return self.transport.perform_request(
#     333             "HEAD", _make_path(index), params=params, headers=headers
#     334         )
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     411                     # raise exception on last retry
#     412                     if attempt == self.max_retries:
# --> 413                         raise e
#     414                 else:
#     415                     raise e
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     379
#     380             try:
# --> 381                 status, headers_response, data = connection.perform_request(
#     382                     method,
#     383                     url,
#
# ~/opt/anaconda3/envs/es/lib/python3.9/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     264             if isinstance(e, ReadTimeoutError):
#     265                 raise ConnectionTimeout("TIMEOUT", str(e), e)
# --> 266             raise ConnectionError("N/A", str(e), e)
#     267
#     268         # raise warnings if any from the 'Warnings' header.
#
# ConnectionError: ConnectionError(<urllib3.connection.HTTPConnection object at 0x7f9ae84383a0>: Failed to establish a new connection: [Errno 61] Connection refused) caused by: NewConnectionError(<urllib3.connection.HTTPConnection object at 0x7f9ae84383a0>: Failed to establish a new connection: [Errno 61] Connection refused)
